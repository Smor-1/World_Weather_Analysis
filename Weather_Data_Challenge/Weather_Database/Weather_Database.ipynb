# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries

import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations

# *** NOTE THAT I AM SETTING THE PROPER RANGE FOR MY LONGITUDES (-180 to 180 degrees) RATHER THAN -90 to 90, hope this is okay! 

lats = np.random.uniform(-90,90,2000)
lngs = np.random.uniform(-180,180,2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations

lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list

coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities

cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module

for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count

#734 cities 

len(cities)
# Out:
# 734

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call

url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description" : weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | sovetskaya
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | kajaani
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | egvekinot
# Processing Record 12 of Set 1 | arrifes
# Processing Record 13 of Set 1 | codrington
# Processing Record 14 of Set 1 | mao
# Processing Record 15 of Set 1 | clyde river
# Processing Record 16 of Set 1 | itapirapua
# Processing Record 17 of Set 1 | caernarfon
# Processing Record 18 of Set 1 | ryotsu
# Processing Record 19 of Set 1 | tromso
# Processing Record 20 of Set 1 | chokurdakh
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | tura
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | mbandaka
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | upernavik
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | gondal
# Processing Record 31 of Set 1 | havre-saint-pierre
# Processing Record 32 of Set 1 | georgetown
# Processing Record 33 of Set 1 | balikpapan
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | howard
# Processing Record 37 of Set 1 | komsomolskiy
# Processing Record 38 of Set 1 | katsuura
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | ancona
# Processing Record 41 of Set 1 | asau
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | oranjestad
# Processing Record 44 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 1 | mopti
# Processing Record 46 of Set 1 | cidreira
# Processing Record 47 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 1 | pisco
# Processing Record 49 of Set 1 | baykit
# Processing Record 50 of Set 1 | cairns
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | hasaki
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | hithadhoo
# Processing Record 5 of Set 2 | mahebourg
# Processing Record 6 of Set 2 | madarounfa
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | shache
# Processing Record 9 of Set 2 | gushikawa
# Processing Record 10 of Set 2 | bermeo
# Processing Record 11 of Set 2 | kaeo
# Processing Record 12 of Set 2 | sovetskiy
# Processing Record 13 of Set 2 | vila
# Processing Record 14 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | akyab
# Processing Record 19 of Set 2 | dikson
# Processing Record 20 of Set 2 | adrar
# Processing Record 21 of Set 2 | kholm
# Processing Record 22 of Set 2 | boguchany
# Processing Record 23 of Set 2 | sitka
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | eureka
# Processing Record 27 of Set 2 | kaitangata
# Processing Record 28 of Set 2 | hervey bay
# Processing Record 29 of Set 2 | isangel
# Processing Record 30 of Set 2 | colares
# Processing Record 31 of Set 2 | alice springs
# Processing Record 32 of Set 2 | punta arenas
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | tuktoyaktuk
# Processing Record 35 of Set 2 | flin flon
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 2 | vestmannaeyjar
# Processing Record 39 of Set 2 | mae hong son
# Processing Record 40 of Set 2 | kletnya
# Processing Record 41 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 2 | anadyr
# Processing Record 43 of Set 2 | alofi
# Processing Record 44 of Set 2 | nome
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | bambous virieux
# Processing Record 47 of Set 2 | husavik
# Processing Record 48 of Set 2 | qasigiannguit
# Processing Record 49 of Set 2 | hilo
# Processing Record 50 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 3 | prince george
# Processing Record 2 of Set 3 | gizo
# Processing Record 3 of Set 3 | portland
# Processing Record 4 of Set 3 | faanui
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | hobyo
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | leningradskiy
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | ilhabela
# Processing Record 12 of Set 3 | port keats
# Processing Record 13 of Set 3 | lata
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | saint george
# Processing Record 16 of Set 3 | beringovskiy
# Processing Record 17 of Set 3 | aleksandrov gay
# Processing Record 18 of Set 3 | ostrovnoy
# Processing Record 19 of Set 3 | ko samui
# Processing Record 20 of Set 3 | middelkerke
# Processing Record 21 of Set 3 | makasar
# Processing Record 22 of Set 3 | thompson
# Processing Record 23 of Set 3 | kapaa
# Processing Record 24 of Set 3 | bethel
# Processing Record 25 of Set 3 | esperance
# Processing Record 26 of Set 3 | springfield
# Processing Record 27 of Set 3 | goedereede
# Processing Record 28 of Set 3 | albany
# Processing Record 29 of Set 3 | jamestown
# Processing Record 30 of Set 3 | praya
# Processing Record 31 of Set 3 | akureyri
# Processing Record 32 of Set 3 | charters towers
# Processing Record 33 of Set 3 | port alfred
# Processing Record 34 of Set 3 | kruisfontein
# Processing Record 35 of Set 3 | hofn
# Processing Record 36 of Set 3 | yeppoon
# Processing Record 37 of Set 3 | kabalo
# Processing Record 38 of Set 3 | port elizabeth
# Processing Record 39 of Set 3 | ferry pass
# Processing Record 40 of Set 3 | taltal
# Processing Record 41 of Set 3 | dubna
# Processing Record 42 of Set 3 | effium
# Processing Record 43 of Set 3 | nortelandia
# Processing Record 44 of Set 3 | leh
# Processing Record 45 of Set 3 | cherskiy
# Processing Record 46 of Set 3 | marystown
# Processing Record 47 of Set 3 | marsh harbour
# Processing Record 48 of Set 3 | sao filipe
# Processing Record 49 of Set 3 | geresk
# City not found. Skipping...
# Processing Record 50 of Set 3 | iqaluit
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | biltine
# Processing Record 3 of Set 4 | yulara
# Processing Record 4 of Set 4 | lavrentiya
# Processing Record 5 of Set 4 | jedovnice
# Processing Record 6 of Set 4 | salalah
# Processing Record 7 of Set 4 | axim
# Processing Record 8 of Set 4 | fukue
# Processing Record 9 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 10 of Set 4 | jinxiang
# Processing Record 11 of Set 4 | longyearbyen
# Processing Record 12 of Set 4 | sohag
# Processing Record 13 of Set 4 | avera
# Processing Record 14 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 4 | illela
# Processing Record 16 of Set 4 | wuwei
# Processing Record 17 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 4 | ilulissat
# Processing Record 19 of Set 4 | seddon
# Processing Record 20 of Set 4 | pontianak
# Processing Record 21 of Set 4 | vostok
# Processing Record 22 of Set 4 | mnogovershinnyy
# Processing Record 23 of Set 4 | saldanha
# Processing Record 24 of Set 4 | north bend
# Processing Record 25 of Set 4 | yokote
# Processing Record 26 of Set 4 | fort saint james
# Processing Record 27 of Set 4 | selikhino
# Processing Record 28 of Set 4 | cranbrook
# Processing Record 29 of Set 4 | kahului
# Processing Record 30 of Set 4 | mar del plata
# Processing Record 31 of Set 4 | new norfolk
# Processing Record 32 of Set 4 | aklavik
# Processing Record 33 of Set 4 | ponta do sol
# Processing Record 34 of Set 4 | ancud
# Processing Record 35 of Set 4 | thabazimbi
# Processing Record 36 of Set 4 | olafsvik
# Processing Record 37 of Set 4 | cabo san lucas
# Processing Record 38 of Set 4 | margate
# Processing Record 39 of Set 4 | nishihara
# Processing Record 40 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 4 | manta
# Processing Record 42 of Set 4 | simcoe
# Processing Record 43 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 4 | gladstone
# Processing Record 45 of Set 4 | lebu
# Processing Record 46 of Set 4 | bandarbeyla
# Processing Record 47 of Set 4 | luderitz
# Processing Record 48 of Set 4 | bathsheba
# Processing Record 49 of Set 4 | puerto ayora
# Processing Record 50 of Set 4 | dakoro
# Processing Record 1 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 5 | camacha
# Processing Record 3 of Set 5 | stalowa wola
# Processing Record 4 of Set 5 | gobabis
# Processing Record 5 of Set 5 | kambove
# Processing Record 6 of Set 5 | comodoro rivadavia
# Processing Record 7 of Set 5 | krutikha
# Processing Record 8 of Set 5 | honiara
# Processing Record 9 of Set 5 | sioux lookout
# Processing Record 10 of Set 5 | necochea
# Processing Record 11 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 5 | okha
# Processing Record 13 of Set 5 | laureles
# Processing Record 14 of Set 5 | kamogawa
# Processing Record 15 of Set 5 | nidda
# Processing Record 16 of Set 5 | yerbogachen
# Processing Record 17 of Set 5 | kavaratti
# Processing Record 18 of Set 5 | hokitika
# Processing Record 19 of Set 5 | dori
# Processing Record 20 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 5 | coahuayana
# Processing Record 22 of Set 5 | bela vista de goias
# Processing Record 23 of Set 5 | rastede
# Processing Record 24 of Set 5 | kralendijk
# Processing Record 25 of Set 5 | antofagasta
# Processing Record 26 of Set 5 | palmer
# Processing Record 27 of Set 5 | lerwick
# Processing Record 28 of Set 5 | lumeje
# Processing Record 29 of Set 5 | ormara
# Processing Record 30 of Set 5 | kabinda
# Processing Record 31 of Set 5 | ambon
# Processing Record 32 of Set 5 | moroni
# Processing Record 33 of Set 5 | swift current
# Processing Record 34 of Set 5 | nelson bay
# Processing Record 35 of Set 5 | henties bay
# Processing Record 36 of Set 5 | pangnirtung
# Processing Record 37 of Set 5 | los llanos de aridane
# Processing Record 38 of Set 5 | lorengau
# Processing Record 39 of Set 5 | jutai
# Processing Record 40 of Set 5 | paita
# Processing Record 41 of Set 5 | mehamn
# Processing Record 42 of Set 5 | ossora
# Processing Record 43 of Set 5 | carrollton
# Processing Record 44 of Set 5 | makakilo city
# Processing Record 45 of Set 5 | san juan
# Processing Record 46 of Set 5 | andenes
# Processing Record 47 of Set 5 | bengkulu
# Processing Record 48 of Set 5 | san cristobal
# Processing Record 49 of Set 5 | port blair
# Processing Record 50 of Set 5 | broome
# Processing Record 1 of Set 6 | ayr
# Processing Record 2 of Set 6 | pingliang
# Processing Record 3 of Set 6 | vila franca do campo
# Processing Record 4 of Set 6 | ibirama
# Processing Record 5 of Set 6 | narsaq
# Processing Record 6 of Set 6 | goundam
# Processing Record 7 of Set 6 | la ronge
# Processing Record 8 of Set 6 | rawson
# Processing Record 9 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 6 | changzhou
# Processing Record 11 of Set 6 | waingapu
# Processing Record 12 of Set 6 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 13 of Set 6 | neiafu
# Processing Record 14 of Set 6 | trairi
# Processing Record 15 of Set 6 | tiksi
# Processing Record 16 of Set 6 | atbasar
# Processing Record 17 of Set 6 | dhidhdhoo
# Processing Record 18 of Set 6 | severo-kurilsk
# Processing Record 19 of Set 6 | sur
# Processing Record 20 of Set 6 | bonthe
# Processing Record 21 of Set 6 | vitimskiy
# City not found. Skipping...
# Processing Record 22 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 23 of Set 6 | te anau
# Processing Record 24 of Set 6 | buala
# Processing Record 25 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 6 | berlevag
# Processing Record 27 of Set 6 | vrises
# Processing Record 28 of Set 6 | cayenne
# Processing Record 29 of Set 6 | kununurra
# Processing Record 30 of Set 6 | luena
# Processing Record 31 of Set 6 | eyl
# Processing Record 32 of Set 6 | jand
# Processing Record 33 of Set 6 | lincoln
# Processing Record 34 of Set 6 | srednekolymsk
# Processing Record 35 of Set 6 | laguna
# Processing Record 36 of Set 6 | mount gambier
# Processing Record 37 of Set 6 | ous
# Processing Record 38 of Set 6 | canaries
# Processing Record 39 of Set 6 | viedma
# Processing Record 40 of Set 6 | de aar
# Processing Record 41 of Set 6 | atar
# Processing Record 42 of Set 6 | ust-tsilma
# Processing Record 43 of Set 6 | aniva
# Processing Record 44 of Set 6 | la reforma
# Processing Record 45 of Set 6 | vardo
# Processing Record 46 of Set 6 | burnie
# Processing Record 47 of Set 6 | broken hill
# Processing Record 48 of Set 6 | banjarmasin
# Processing Record 49 of Set 6 | launceston
# Processing Record 50 of Set 6 | narwana
# Processing Record 1 of Set 7 | kiruna
# Processing Record 2 of Set 7 | voh
# Processing Record 3 of Set 7 | grindavik
# Processing Record 4 of Set 7 | westport
# Processing Record 5 of Set 7 | thoen
# Processing Record 6 of Set 7 | omboue
# Processing Record 7 of Set 7 | hunchun
# Processing Record 8 of Set 7 | hamilton
# Processing Record 9 of Set 7 | amurzet
# Processing Record 10 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 11 of Set 7 | waitati
# Processing Record 12 of Set 7 | yumen
# Processing Record 13 of Set 7 | deputatskiy
# Processing Record 14 of Set 7 | punta de bombon
# Processing Record 15 of Set 7 | kamina
# Processing Record 16 of Set 7 | cobija
# Processing Record 17 of Set 7 | inhambane
# Processing Record 18 of Set 7 | kavieng
# Processing Record 19 of Set 7 | grand-lahou
# Processing Record 20 of Set 7 | kedrovyy
# Processing Record 21 of Set 7 | ust-maya
# Processing Record 22 of Set 7 | puerto colombia
# Processing Record 23 of Set 7 | sao joao da barra
# Processing Record 24 of Set 7 | anchorage
# Processing Record 25 of Set 7 | skibbereen
# Processing Record 26 of Set 7 | sabang
# Processing Record 27 of Set 7 | kirakira
# Processing Record 28 of Set 7 | turbat
# Processing Record 29 of Set 7 | aras
# Processing Record 30 of Set 7 | udachnyy
# Processing Record 31 of Set 7 | xiuyan
# Processing Record 32 of Set 7 | contai
# Processing Record 33 of Set 7 | polunochnoye
# Processing Record 34 of Set 7 | sembakung
# Processing Record 35 of Set 7 | san quintin
# Processing Record 36 of Set 7 | oktyabrskoye
# Processing Record 37 of Set 7 | tucuman
# Processing Record 38 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 39 of Set 7 | cambridge
# Processing Record 40 of Set 7 | belyy yar
# Processing Record 41 of Set 7 | guinguineo
# Processing Record 42 of Set 7 | lagoa
# Processing Record 43 of Set 7 | penzance
# Processing Record 44 of Set 7 | beroroha
# Processing Record 45 of Set 7 | sosnovo-ozerskoye
# Processing Record 46 of Set 7 | labuan
# Processing Record 47 of Set 7 | matagami
# Processing Record 48 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 49 of Set 7 | sal rei
# Processing Record 50 of Set 7 | bonnyville
# Processing Record 1 of Set 8 | touros
# Processing Record 2 of Set 8 | waddan
# Processing Record 3 of Set 8 | fortuna
# Processing Record 4 of Set 8 | khanpur
# Processing Record 5 of Set 8 | lompoc
# Processing Record 6 of Set 8 | malindi
# Processing Record 7 of Set 8 | oktyabrskiy
# Processing Record 8 of Set 8 | oistins
# Processing Record 9 of Set 8 | yokadouma
# Processing Record 10 of Set 8 | cap malheureux
# Processing Record 11 of Set 8 | sydney
# Processing Record 12 of Set 8 | kanniyakumari
# Processing Record 13 of Set 8 | torbay
# Processing Record 14 of Set 8 | cajati
# Processing Record 15 of Set 8 | luganville
# Processing Record 16 of Set 8 | jalu
# Processing Record 17 of Set 8 | tuatapere
# Processing Record 18 of Set 8 | pimentel
# Processing Record 19 of Set 8 | bikin
# Processing Record 20 of Set 8 | albina
# Processing Record 21 of Set 8 | rafai
# Processing Record 22 of Set 8 | acapulco
# Processing Record 23 of Set 8 | tilichiki
# Processing Record 24 of Set 8 | guerrero negro
# Processing Record 25 of Set 8 | prince rupert
# Processing Record 26 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 27 of Set 8 | bridlington
# Processing Record 28 of Set 8 | ust-nera
# Processing Record 29 of Set 8 | mandali
# Processing Record 30 of Set 8 | dingzhou
# Processing Record 31 of Set 8 | kurumkan
# Processing Record 32 of Set 8 | norman wells
# Processing Record 33 of Set 8 | shetpe
# Processing Record 34 of Set 8 | saint anthony
# Processing Record 35 of Set 8 | palmi
# Processing Record 36 of Set 8 | grand gaube
# Processing Record 37 of Set 8 | graham
# Processing Record 38 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 39 of Set 8 | shelburne
# Processing Record 40 of Set 8 | labuhan
# Processing Record 41 of Set 8 | santa rosa
# Processing Record 42 of Set 8 | bilma
# Processing Record 43 of Set 8 | bosaso
# Processing Record 44 of Set 8 | sibolga
# Processing Record 45 of Set 8 | krasnoselkup
# Processing Record 46 of Set 8 | secunda
# Processing Record 47 of Set 8 | brae
# Processing Record 48 of Set 8 | wasilla
# Processing Record 49 of Set 8 | benguela
# Processing Record 50 of Set 8 | muravlenko
# Processing Record 1 of Set 9 | wewak
# Processing Record 2 of Set 9 | la plata
# Processing Record 3 of Set 9 | wicklow
# Processing Record 4 of Set 9 | kaabong
# Processing Record 5 of Set 9 | umm lajj
# Processing Record 6 of Set 9 | zhangye
# Processing Record 7 of Set 9 | machinga
# Processing Record 8 of Set 9 | apache junction
# Processing Record 9 of Set 9 | bilibino
# Processing Record 10 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 9 | stornoway
# Processing Record 12 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 9 | pevek
# Processing Record 15 of Set 9 | beloha
# Processing Record 16 of Set 9 | saskylakh
# Processing Record 17 of Set 9 | chateauroux
# Processing Record 18 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 9 | buta
# Processing Record 20 of Set 9 | singaparna
# Processing Record 21 of Set 9 | rancho palos verdes
# Processing Record 22 of Set 9 | port lincoln
# Processing Record 23 of Set 9 | auki
# Processing Record 24 of Set 9 | berbera
# Processing Record 25 of Set 9 | fort nelson
# Processing Record 26 of Set 9 | pocatello
# Processing Record 27 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 9 | alihe
# Processing Record 29 of Set 9 | megion
# Processing Record 30 of Set 9 | buin
# Processing Record 31 of Set 9 | yenagoa
# Processing Record 32 of Set 9 | souillac
# Processing Record 33 of Set 9 | axixa do tocantins
# City not found. Skipping...
# Processing Record 34 of Set 9 | lazaro cardenas
# Processing Record 35 of Set 9 | alta
# Processing Record 36 of Set 9 | sumenep
# Processing Record 37 of Set 9 | port macquarie
# Processing Record 38 of Set 9 | derbent
# Processing Record 39 of Set 9 | naryan-mar
# Processing Record 40 of Set 9 | sindand
# City not found. Skipping...
# Processing Record 41 of Set 9 | freeport
# Processing Record 42 of Set 9 | inirida
# Processing Record 43 of Set 9 | saint-augustin
# Processing Record 44 of Set 9 | urrao
# Processing Record 45 of Set 9 | vanavara
# Processing Record 46 of Set 9 | richards bay
# Processing Record 47 of Set 9 | mitrofanovka
# Processing Record 48 of Set 9 | awjilah
# Processing Record 49 of Set 9 | waipawa
# Processing Record 50 of Set 9 | puro
# Processing Record 1 of Set 10 | gebre guracha
# Processing Record 2 of Set 10 | behshahr
# Processing Record 3 of Set 10 | urumqi
# Processing Record 4 of Set 10 | rethimnon
# Processing Record 5 of Set 10 | geraldton
# Processing Record 6 of Set 10 | carlibaba
# Processing Record 7 of Set 10 | khislavichi
# Processing Record 8 of Set 10 | sorland
# Processing Record 9 of Set 10 | bubaque
# Processing Record 10 of Set 10 | caravelas
# Processing Record 11 of Set 10 | lapeer
# Processing Record 12 of Set 10 | zhigalovo
# Processing Record 13 of Set 10 | meulaboh
# Processing Record 14 of Set 10 | give
# Processing Record 15 of Set 10 | iquique
# Processing Record 16 of Set 10 | apitong
# Processing Record 17 of Set 10 | batticaloa
# Processing Record 18 of Set 10 | taksimo
# Processing Record 19 of Set 10 | diffa
# Processing Record 20 of Set 10 | druzhba
# Processing Record 21 of Set 10 | tara
# Processing Record 22 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 23 of Set 10 | morgan city
# Processing Record 24 of Set 10 | ulladulla
# Processing Record 25 of Set 10 | oskarshamn
# Processing Record 26 of Set 10 | lalibela
# Processing Record 27 of Set 10 | sinnamary
# Processing Record 28 of Set 10 | aiquile
# Processing Record 29 of Set 10 | zavallya
# Processing Record 30 of Set 10 | coihaique
# Processing Record 31 of Set 10 | olinda
# Processing Record 32 of Set 10 | raudeberg
# Processing Record 33 of Set 10 | shimoda
# Processing Record 34 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 10 | pueblo
# Processing Record 36 of Set 10 | buraydah
# Processing Record 37 of Set 10 | puerto madero
# Processing Record 38 of Set 10 | sijunjung
# Processing Record 39 of Set 10 | kumluca
# Processing Record 40 of Set 10 | ballina
# Processing Record 41 of Set 10 | dangara
# Processing Record 42 of Set 10 | loreto
# Processing Record 43 of Set 10 | amazar
# Processing Record 44 of Set 10 | dunmore town
# Processing Record 45 of Set 10 | najran
# Processing Record 46 of Set 10 | bozeman
# Processing Record 47 of Set 10 | shingu
# Processing Record 48 of Set 10 | zlitan
# Processing Record 49 of Set 10 | gejiu
# Processing Record 50 of Set 10 | wairoa
# Processing Record 1 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 11 | cravo norte
# Processing Record 3 of Set 11 | empalme
# Processing Record 4 of Set 11 | mouzakion
# City not found. Skipping...
# Processing Record 5 of Set 11 | kuching
# Processing Record 6 of Set 11 | vanimo
# Processing Record 7 of Set 11 | dingle
# Processing Record 8 of Set 11 | gat
# Processing Record 9 of Set 11 | autazes
# Processing Record 10 of Set 11 | clermont
# Processing Record 11 of Set 11 | teguldet
# Processing Record 12 of Set 11 | campbell river
# Processing Record 13 of Set 11 | nanortalik
# Processing Record 14 of Set 11 | rocha
# Processing Record 15 of Set 11 | beaufort
# Processing Record 16 of Set 11 | whitehorse
# Processing Record 17 of Set 11 | namibe
# Processing Record 18 of Set 11 | otjiwarongo
# Processing Record 19 of Set 11 | iquitos
# Processing Record 20 of Set 11 | alakurtti
# Processing Record 21 of Set 11 | yamada
# Processing Record 22 of Set 11 | kanigoro
# Processing Record 23 of Set 11 | omsukchan
# Processing Record 24 of Set 11 | sturgis
# Processing Record 25 of Set 11 | choma
# Processing Record 26 of Set 11 | kalmunai
# Processing Record 27 of Set 11 | taoudenni
# Processing Record 28 of Set 11 | dudinka
# Processing Record 29 of Set 11 | kodiak
# Processing Record 30 of Set 11 | baghdad
# Processing Record 31 of Set 11 | izumo
# Processing Record 32 of Set 11 | manakara
# Processing Record 33 of Set 11 | prabumulih
# Processing Record 34 of Set 11 | saint-georges
# Processing Record 35 of Set 11 | tateyama
# Processing Record 36 of Set 11 | finote selam
# Processing Record 37 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 11 | vila velha
# Processing Record 39 of Set 11 | roma
# Processing Record 40 of Set 11 | esil
# Processing Record 41 of Set 11 | manchester
# Processing Record 42 of Set 11 | goba
# Processing Record 43 of Set 11 | naze
# Processing Record 44 of Set 11 | sakakah
# Processing Record 45 of Set 11 | vao
# Processing Record 46 of Set 11 | kurilsk
# Processing Record 47 of Set 11 | rio grande
# Processing Record 48 of Set 11 | williamsburg
# Processing Record 49 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 50 of Set 11 | dunedin
# Processing Record 1 of Set 12 | saint-pierre
# Processing Record 2 of Set 12 | save
# Processing Record 3 of Set 12 | kloulklubed
# Processing Record 4 of Set 12 | scottsbluff
# Processing Record 5 of Set 12 | katherine
# Processing Record 6 of Set 12 | hajnowka
# Processing Record 7 of Set 12 | xiamen
# Processing Record 8 of Set 12 | manacapuru
# Processing Record 9 of Set 12 | moranbah
# Processing Record 10 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 12 | bonavista
# Processing Record 12 of Set 12 | ambilobe
# Processing Record 13 of Set 12 | jumla
# Processing Record 14 of Set 12 | katima mulilo
# Processing Record 15 of Set 12 | brownwood
# Processing Record 16 of Set 12 | gwanda
# Processing Record 17 of Set 12 | matveyevka
# Processing Record 18 of Set 12 | forio
# Processing Record 19 of Set 12 | slave lake
# Processing Record 20 of Set 12 | acarau
# Processing Record 21 of Set 12 | morro bay
# Processing Record 22 of Set 12 | sao sebastiao
# Processing Record 23 of Set 12 | port hardy
# Processing Record 24 of Set 12 | victor harbor
# Processing Record 25 of Set 12 | tahoua
# Processing Record 26 of Set 12 | cuiaba
# Processing Record 27 of Set 12 | elmira
# Processing Record 28 of Set 12 | sao domingos do maranhao
# Processing Record 29 of Set 12 | braganca paulista
# Processing Record 30 of Set 12 | rorvik
# Processing Record 31 of Set 12 | aron
# Processing Record 32 of Set 12 | amahai
# Processing Record 33 of Set 12 | fremont
# Processing Record 34 of Set 12 | airai
# Processing Record 35 of Set 12 | moron
# Processing Record 36 of Set 12 | malatya
# Processing Record 37 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 38 of Set 12 | denpasar
# Processing Record 39 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 40 of Set 12 | tazovskiy
# Processing Record 41 of Set 12 | leghorn
# City not found. Skipping...
# Processing Record 42 of Set 12 | port augusta
# Processing Record 43 of Set 12 | tessalit
# Processing Record 44 of Set 12 | arti
# Processing Record 45 of Set 12 | mercedes
# Processing Record 46 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 12 | vodnyy
# Processing Record 48 of Set 12 | pemba
# Processing Record 49 of Set 12 | teguise
# Processing Record 50 of Set 12 | roald
# Processing Record 1 of Set 13 | aripuana
# Processing Record 2 of Set 13 | hammerfest
# Processing Record 3 of Set 13 | ibra
# Processing Record 4 of Set 13 | dzilam gonzalez
# Processing Record 5 of Set 13 | sechelt
# Processing Record 6 of Set 13 | houma
# Processing Record 7 of Set 13 | takaka
# Processing Record 8 of Set 13 | nurota
# Processing Record 9 of Set 13 | poum
# Processing Record 10 of Set 13 | dalbandin
# Processing Record 11 of Set 13 | pontal do parana
# Processing Record 12 of Set 13 | xudat
# Processing Record 13 of Set 13 | sayanogorsk
# Processing Record 14 of Set 13 | tautira
# Processing Record 15 of Set 13 | djambala
# Processing Record 16 of Set 13 | faya
# Processing Record 17 of Set 13 | montrose
# Processing Record 18 of Set 13 | road town
# Processing Record 19 of Set 13 | araripina
# Processing Record 20 of Set 13 | rock springs
# Processing Record 21 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 23 of Set 13 | qaqortoq
# Processing Record 24 of Set 13 | impfondo
# Processing Record 25 of Set 13 | concarneau
# Processing Record 26 of Set 13 | asosa
# Processing Record 27 of Set 13 | gairo
# Processing Record 28 of Set 13 | sungai padi
# Processing Record 29 of Set 13 | venado tuerto
# Processing Record 30 of Set 13 | synya
# Processing Record 31 of Set 13 | bury saint edmunds
# City not found. Skipping...
# Processing Record 32 of Set 13 | muros
# Processing Record 33 of Set 13 | whitianga
# Processing Record 34 of Set 13 | ajjampur
# Processing Record 35 of Set 13 | golspie
# Processing Record 36 of Set 13 | darnah
# Processing Record 37 of Set 13 | wum
# Processing Record 38 of Set 13 | talnakh
# Processing Record 39 of Set 13 | kasulu
# Processing Record 40 of Set 13 | balsas
# Processing Record 41 of Set 13 | cascais
# Processing Record 42 of Set 13 | rovaniemi
# Processing Record 43 of Set 13 | miyako
# Processing Record 44 of Set 13 | talara
# Processing Record 45 of Set 13 | byron bay
# Processing Record 46 of Set 13 | koundara
# Processing Record 47 of Set 13 | ust-kuyga
# Processing Record 48 of Set 13 | hede
# Processing Record 49 of Set 13 | chapais
# Processing Record 50 of Set 13 | teya
# Processing Record 1 of Set 14 | alenquer
# Processing Record 2 of Set 14 | nouadhibou
# Processing Record 3 of Set 14 | tevaitoa
# Processing Record 4 of Set 14 | zelenyy bor
# Processing Record 5 of Set 14 | sampit
# Processing Record 6 of Set 14 | zavodouspenskoye
# Processing Record 7 of Set 14 | lotofaga
# Processing Record 8 of Set 14 | ahtopol
# Processing Record 9 of Set 14 | daru
# Processing Record 10 of Set 14 | cocal
# Processing Record 11 of Set 14 | cockburn town
# Processing Record 12 of Set 14 | novoagansk
# Processing Record 13 of Set 14 | iracoubo
# Processing Record 14 of Set 14 | calama
# Processing Record 15 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 14 | cheremshanka
# Processing Record 18 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 14 | kabompo
# Processing Record 20 of Set 14 | buchanan
# Processing Record 21 of Set 14 | mackay
# Processing Record 22 of Set 14 | ljungby
# Processing Record 23 of Set 14 | biak
# Processing Record 24 of Set 14 | gudari
# Processing Record 25 of Set 14 | meiktila
# Processing Record 26 of Set 14 | susuman
# Processing Record 27 of Set 14 | azuaga
# Processing Record 28 of Set 14 | hambantota
# Processing Record 29 of Set 14 | jiuquan
# Processing Record 30 of Set 14 | fort myers beach
# Processing Record 31 of Set 14 | morondava
# Processing Record 32 of Set 14 | uyemskiy
# Processing Record 33 of Set 14 | tondano
# Processing Record 34 of Set 14 | tomigusuku
# Processing Record 35 of Set 14 | bossier city
# Processing Record 36 of Set 14 | bijar
# Processing Record 37 of Set 14 | merauke
# Processing Record 38 of Set 14 | thongwa
# Processing Record 39 of Set 14 | praia
# Processing Record 40 of Set 14 | saint-francois
# Processing Record 41 of Set 14 | high level
# Processing Record 42 of Set 14 | roebourne
# Processing Record 43 of Set 14 | dwarka
# Processing Record 44 of Set 14 | quesnel
# Processing Record 45 of Set 14 | matay
# Processing Record 46 of Set 14 | atasu
# Processing Record 47 of Set 14 | takoradi
# Processing Record 48 of Set 14 | mackenzie
# Processing Record 49 of Set 14 | kailua
# Processing Record 50 of Set 14 | maniitsoq
# Processing Record 1 of Set 15 | excelsior springs
# Processing Record 2 of Set 15 | sisimiut
# Processing Record 3 of Set 15 | tarakan
# Processing Record 4 of Set 15 | batemans bay
# Processing Record 5 of Set 15 | saint-joseph
# Processing Record 6 of Set 15 | peace river
# Processing Record 7 of Set 15 | geilo
# Processing Record 8 of Set 15 | furstenfeld
# Processing Record 9 of Set 15 | suhbaatar
# Processing Record 10 of Set 15 | porto walter
# Processing Record 11 of Set 15 | uthal
# Processing Record 12 of Set 15 | petropavlovka
# Processing Record 13 of Set 15 | tifton
# Processing Record 14 of Set 15 | wattegama
# Processing Record 15 of Set 15 | merritt
# Processing Record 16 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 17 of Set 15 | zyryanka
# Processing Record 18 of Set 15 | salta
# Processing Record 19 of Set 15 | miramar
# Processing Record 20 of Set 15 | walvis bay
# Processing Record 21 of Set 15 | rongcheng
# Processing Record 22 of Set 15 | keningau
# Processing Record 23 of Set 15 | santa cruz
# Processing Record 24 of Set 15 | a
# City not found. Skipping...
# Processing Record 25 of Set 15 | kasongo-lunda
# Processing Record 26 of Set 15 | talcahuano
# Processing Record 27 of Set 15 | zonguldak
# Processing Record 28 of Set 15 | maceio
# Processing Record 29 of Set 15 | revelstoke
# Processing Record 30 of Set 15 | abu kamal
# Processing Record 31 of Set 15 | tanout
# Processing Record 32 of Set 15 | nova londrina
# Processing Record 33 of Set 15 | iturama
# Processing Record 34 of Set 15 | half moon bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have

#678

len(city_data)
# Out:
# 678

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_col_order = ["City" , "Country" , "Lat" , "Lng" , "Max Temp" , "Humidity" , "Cloudiness" , "Wind Speed" , "Current Description"]
city_data_df = city_data_df[new_col_order]
city_data_df.to_csv("../Weather_Database/WeatherPy_Database.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9m/xp265wv97bl6mhlqzr9f1wcr0000gn/T/ipykernel_20057/2585492308.py in <module>
#       1 # Use the city_data list to create a new pandas DataFrame.
# ----> 2 city_data_df = pd.DataFrame(city_data)
#       3 new_col_order = ["City" , "Country" , "Lat" , "Lng" , "Max Temp" , "Humidity" , "Cloudiness" , "Wind Speed" , "Current Description"]
#       4 city_data_df = city_data_df[new_col_order]
#       5 city_data_df.to_csv("WeatherPy_Database.csv")
#
# NameError: name 'city_data' is not defined

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tasiilaq      GL  65.6145  -37.6368    -15.89        66         100
# 1       Busselton      AU -33.6500  115.3333     15.75        67           2
# 2  Ribeira Grande      PT  38.5167  -28.7000     18.22        88          40
# 3         Ushuaia      AR -54.8000  -68.3000     13.81        58          75
# 4      Sovetskaya      RU  44.7769   41.1722     -0.63        77           0
# 5         Mataura      NZ -46.1927  168.8643      7.73        98          51
# 6         Kajaani      FI  64.2273   27.7285      1.03        93         100
# 7           Vaini      TO -21.2000 -175.2000     26.09        94          75
# 8       Egvekinot      RU  66.3167 -179.1667    -25.05        88          24
# 9         Arrifes      PT  37.7667  -25.7000     17.14        88          40
#
#    Wind Speed Current Description
# 0        2.03     overcast clouds
# 1        8.76           clear sky
# 2       12.52    scattered clouds
# 3        6.69       broken clouds
# 4        4.70           clear sky
# 5        0.42       broken clouds
# 6        3.60     overcast clouds
# 7        0.51       moderate rain
# 8        5.56          few clouds
# 9        6.69    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"



#    *** NOTE THAT I COMPLETED THIS ABOVE *** 



# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data

city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tasiilaq      GL  65.6145  -37.6368    -15.89        66         100
# 1       Busselton      AU -33.6500  115.3333     15.75        67           2
# 2  Ribeira Grande      PT  38.5167  -28.7000     18.22        88          40
# 3         Ushuaia      AR -54.8000  -68.3000     13.81        58          75
# 4      Sovetskaya      RU  44.7769   41.1722     -0.63        77           0
# 5         Mataura      NZ -46.1927  168.8643      7.73        98          51
# 6         Kajaani      FI  64.2273   27.7285      1.03        93         100
# 7           Vaini      TO -21.2000 -175.2000     26.09        94          75
# 8       Egvekinot      RU  66.3167 -179.1667    -25.05        88          24
# 9         Arrifes      PT  37.7667  -25.7000     17.14        88          40
#
#    Wind Speed Current Description
# 0        2.03     overcast clouds
# 1        8.76           clear sky
# 2       12.52    scattered clouds
# 3        6.69       broken clouds
# 4        4.70           clear sky
# 5        0.42       broken clouds
# 6        3.60     overcast clouds
# 7        0.51       moderate rain
# 8        5.56          few clouds
# 9        6.69    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function

city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name


file_name = "../Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(file_name)


#  *** NOTE THAT I COMPLETED THIS ABOVE , but I can show you again in this cell how I'd do it in this way *** 


# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
